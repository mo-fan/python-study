# %% [markdown]
# # 2.5 综合示例——图像变换

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 图像一般采用的是RGB色彩模式，即每个像素点的颜色由R（红）、G（绿）、B（蓝）组成。通过三种颜色的叠加可以得到各种颜色，每个颜色的取值范围为0～255。Python中的PIL库是一个处理图像的第三方库

# %%
im = np.array(Image.open('./rose.jpg'))
print(im.shape,im.dtype)
# Out:
# (313, 500, 3) uint8

# %%
im
# Out:
# array([[[120, 142, 104],
#         [121, 143, 105],
#         [121, 143, 105],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[120, 142, 104],
#         [120, 142, 104],
#         [121, 143, 105],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[118, 140, 102],
#         [119, 141, 103],
#         [119, 141, 103],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# ### 通过图中的代码可以看出，图像转换成三维数组后，维度分别为宽度、长度和RGB值

# %% [markdown]
# #### 注意：在Anaconda中已经默认安装了PIL库，库名为pillow

# %% [markdown]
# ### 转换为数组后，可进行数组运算，运算完成后将其保存为新图像就完成了图像的变换

# %% [markdown]
# ## 使用matplotlib制作蓝色妖姬

# %%
rose = plt.imread('./rose.jpg')
plt.imshow(rose)

# %%
rose2 = rose[:,:,::-1]

# %%
plt.imshow(rose2)

# %%
plt.imsave('./rose2.jpg',rose2)
